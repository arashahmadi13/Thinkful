# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %matplotlib inline

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'


engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(postgres_user, postgres_pw,
                                                            postgres_host,postgres_port ,postgres_db))

df = pd.read_sql_query('select * from useducation', con=engine)

engine.dispose()
# Out:
# /opt/conda/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# ...

# %%
our_list = df.columns
for column in our_list[3:]:
    df[column].fillna(df[column].interpolate(),inplace=True)
    
df.dropna(inplace=True)    
df.head()
# Out:
#           PRIMARY_KEY         STATE  YEAR       ENROLL  TOTAL_REVENUE  \
# 36       2001_WYOMING       WYOMING  2001   89711.0000       804297.0
# 37      1992_OKLAHOMA      OKLAHOMA  1992  129586.3125      2396705.0
# 38        1992_OREGON        OREGON  1992  169461.6250      2773959.0
# 39  1992_PENNSYLVANIA  PENNSYLVANIA  1992  209336.9375     11257252.0
# 40  1992_RHODE_ISLAND  RHODE_ISLAND  1992  249212.2500       883073.0
#
#     FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 36          69172.0       403021.0       332104.0           787949.0
# 37         211627.0      1470516.0       714562.0          2515272.0
# 38         163544.0       788309.0      1822106.0          2898210.0
# 39         658139.0      4227323.0      6371790.0         11539253.0
# 40          43545.0       329810.0       509718.0           863404.0
#
#     INSTRUCTION_EXPENDITURE  ...  GRADES_4_G  GRADES_8_G  GRADES_12_G  \
# ...

# %% [markdown]
# ## Part (1)

# %%
df["w_score"] = (df["GRADES_4_G"]*((df["AVG_MATH_4_SCORE"] + df["AVG_READING_4_SCORE"])*0.5) + df["GRADES_8_G"]
                                 * ((df["AVG_MATH_8_SCORE"] + df["AVG_READING_8_SCORE"])*0.5))/(df["GRADES_4_G"] + df["GRADES_8_G"])

# %% [markdown]
# ## Part (2)

# %%
df[['w_score','TOTAL_EXPENDITURE','INSTRUCTION_EXPENDITURE','SUPPORT_SERVICES_EXPENDITURE',
       'OTHER_EXPENDITURE','CAPITAL_OUTLAY_EXPENDITURE']].corr()
# Out:
#                                w_score  TOTAL_EXPENDITURE  \
# w_score                       1.000000           0.204239
# TOTAL_EXPENDITURE             0.204239           1.000000
# INSTRUCTION_EXPENDITURE       0.207131           0.992698
# SUPPORT_SERVICES_EXPENDITURE  0.221824           0.992435
# OTHER_EXPENDITURE             0.169775           0.951726
# CAPITAL_OUTLAY_EXPENDITURE    0.128087           0.928129
#
#                               INSTRUCTION_EXPENDITURE  \
# w_score                                      0.207131
# TOTAL_EXPENDITURE                            0.992698
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.979165
# OTHER_EXPENDITURE                            0.920297
# CAPITAL_OUTLAY_EXPENDITURE                   0.895527
#
#                               SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  \
# w_score                                           0.221824           0.169775
# ...

# %% [markdown]
# ## Part(3)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df[["INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE",
                  "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]]

X = StandardScaler().fit_transform(X)

sklearn_pca = PCA(n_components=1)
df["pca_1"] = sklearn_pca.fit_transform(X)

print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)
# Out:
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.94725496]

# %% [markdown]
# ## Part(4)

# %%
df[["overall_score", "pca_1", "TOTAL_EXPENDITURE", "INSTRUCTION_EXPENDITURE",
              "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]].corr()
# Out:
#                               overall_score     pca_1  TOTAL_EXPENDITURE  \
# overall_score                      1.000000  0.187067           0.204239
# pca_1                              0.187067  1.000000           0.992988
# TOTAL_EXPENDITURE                  0.204239  0.992988           1.000000
# INSTRUCTION_EXPENDITURE            0.207131  0.975096           0.992698
# SUPPORT_SERVICES_EXPENDITURE       0.221824  0.986139           0.992435
# OTHER_EXPENDITURE                  0.169775  0.975451           0.951726
# CAPITAL_OUTLAY_EXPENDITURE         0.128087  0.956156           0.928129
#
#                               INSTRUCTION_EXPENDITURE  \
# overall_score                                0.207131
# pca_1                                        0.975096
# TOTAL_EXPENDITURE                            0.992698
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.979165
# OTHER_EXPENDITURE                            0.920297
# ...
